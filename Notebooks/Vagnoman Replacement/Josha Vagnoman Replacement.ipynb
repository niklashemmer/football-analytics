# %%
import pandas as pd
import numpy as np 
import math
from math import sqrt
import matplotlib.pyplot as plt
import collections
import warnings

import seaborn as sns
warnings.filterwarnings("ignore")

#Machine Learning
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import euclidean_distances

# Show all columns of dataframe
pd.set_option("display.max_columns", None)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv("")

# %% [markdown]
# # 1. Data Engineering

# %%
# Create new ID column and Main Position
df["ID"] = df["Player"] + " (" + df["Team"] + ")"# + " " + str(df["Age"]) + ")"
df["Main Position"] = df["Position"].str.split(",", expand=True)[0]

# Place ID as first column
cols = df.columns.tolist()
cols = cols[-2:] + cols[:-2]
df = df[cols]

df.head(1)
# Out:
#                           ID Main Position     Player           Team  \
# 0  F. Bustos (Internacional)            RB  F. Bustos  Internacional
#
#         League Position  Age  Market value Contract expires  Matches played  \
# 0  Argentina 1       RB   26       6000000         31.12.24              23
#
#    Minutes played  Goals    xG  Assists    xA  Duels per 90  Duels won, %  \
# 0            2228      1  0.27        2  1.44         14.87         54.62
#
#   Birth country Passport country   Foot  Height  Weight On loan  \
# 0     Argentina        Argentina  right     167      66      no
#
#    Successful defensive actions per 90  Defensive duels per 90  \
# 0                                 8.56                    5.49
#
#    Defensive duels won, %  Aerial duels per 90  Aerial duels won, %  \
# 0                    62.5                 1.49                48.65
#
#    Sliding tackles per 90  PAdj Sliding tackles  Shots blocked per 90  \
# 0                    0.89                  1.24                  0.16
#
#    Interceptions per 90  PAdj Interceptions  Fouls per 90  Yellow cards  \
# 0                  4.24                5.91          0.36             1
#
#    Yellow cards per 90  Red cards  Red cards per 90  \
# 0                 0.04          0               0.0
#
#    Successful attacking actions per 90  Goals per 90  Non-penalty goals  \
# 0                                 3.23          0.04                  1
#
#    Non-penalty goals per 90  xG per 90  Head goals  Head goals per 90  Shots  \
# 0                      0.04       0.01           0                0.0      6
#
#    Shots per 90  Shots on target, %  Goal conversion, %  Assists per 90  \
# 0          0.24               66.67              16.667            0.08
#
#    Crosses per 90  Accurate crosses, %  Crosses from left flank per 90  \
# 0            2.67                37.88                             0.0
#
#    Accurate crosses from left flank, %  Crosses from right flank per 90  \
# 0                                  0.0                             2.63
#
#    Accurate crosses from right flank, %  Crosses to goalie box per 90  \
# 0                                 38.46                           0.4
#
#    Dribbles per 90  Successful dribbles, %  Offensive duels per 90  \
# 0              2.5                   72.58                    5.17
#
#    Offensive duels won, %  Touches in box per 90  Progressive runs per 90  \
# 0                   57.81                   1.41                      1.9
#
#    Accelerations per 90  Received passes per 90  Received long passes per 90  \
# 0                  0.73                   42.09                         3.19
#
#    Fouls suffered per 90  Passes per 90  Accurate passes, %  \
# 0                   1.25          56.43               80.24
#
#    Forward passes per 90  Accurate forward passes, %  Back passes per 90  \
# 0                  21.49                       73.31                6.99
#
#    Accurate back passes, %  Lateral passes per 90  Accurate lateral passes, %  \
# 0                    87.28                  18.38                       87.25
#
#    Short / medium passes per 90  Accurate short / medium passes, %  \
# 0                         48.03                              86.04
#
#    Long passes per 90  Accurate long passes, %  Average pass length, m  \
# 0                5.86                    51.03                   18.16
#
#    Average long pass length, m  xA per 90  Shot assists per 90  \
# 0                        33.28       0.06                 0.57
#
#    Second assists per 90  Third assists per 90  Smart passes per 90  \
# 0                    0.0                   0.0                 0.44
#
#    Accurate smart passes, %  Key passes per 90  Passes to final third per 90  \
# 0                     54.55               0.44                          7.39
#
#    Accurate passes to final third, %  Passes to penalty area per 90  \
# 0                              75.41                           2.63
#
#    Accurate passes to penalty area, %  Through passes per 90  \
# 0                               49.23                   0.48
#
#    Accurate through passes, %  Deep completions per 90  \
# 0                       33.33                     0.57
#
#    Deep completed crosses per 90  Progressive passes per 90  \
# 0                           0.97                      12.44
#
#    Accurate progressive passes, %  Conceded goals  Conceded goals per 90  \
# 0                           74.68               0                    NaN
#
#    Shots against  Shots against per 90  Clean sheets  Save rate, %  \
# 0              0                   NaN             0           0.0
#
#    xG against  xG against per 90  Prevented goals  Prevented goals per 90  \
# 0         0.0                0.0              NaN                     NaN
#
#    Back passes received as GK per 90  Exits per 90  Aerial duels per 90.1  \
# 0                               0.28           NaN                    NaN
#
#    Free kicks per 90  Direct free kicks per 90  \
# 0                0.0                       0.0
#
#    Direct free kicks on target, %  Corners per 90  Penalties taken  \
# 0                             0.0            0.08                0
#
#    Penalty conversion, %
# 0                    0.0

# %%
# Drop duplicates and reset index
df.drop_duplicates(subset = ["ID"],inplace=True)
df.reset_index(drop=True, inplace=True)
df.head(2)
df.shape
# Out:
# (5585, 117)

# %%
# Drop unnecessary columns
df.drop(columns=["Conceded goals", "Conceded goals per 90",
                "Shots against", "Shots against per 90", "Clean sheets", "Save rate, %", "xG against",
                "xG against per 90", "Prevented goals", "Prevented goals per 90", "Exits per 90",
                "Back passes received as GK per 90", "Aerial duels per 90.1", "Free kicks per 90",
                "Direct free kicks per 90", "Direct free kicks on target, %", "Corners per 90", 
                "Penalties taken", "Penalty conversion, %"], axis=1, inplace=True)

# %% [markdown]
# ### Create additional metrics

# %%
# Ball protection and offensive duels 
df["Ball Protection"] = df["Offensive duels per 90"] - df["Dribbles per 90"]
df["Ball Protection Succ"] = ((df["Offensive duels per 90"] * df["Offensive duels won, %"])/100 - (df["Dribbles per 90"] * df["Successful dribbles, %"])/100).round(2)
df["Ball Protection, %"] = ((df["Ball Protection Succ"] / df["Ball Protection"])*100).round(2)
#print(df.sort_values(by="Ball Protection, %", ascending=False).head(50))

# Turnover (lost offensive duels incl. dribbles)
df["Turnover"] = -(df["Offensive duels per 90"] * ((100-df["Offensive duels won, %"])/100)).round(2)

# Passing tendency 
df["Passing Tendency"] = (df["Forward passes per 90"] / (df["Back passes per 90"] + df["Lateral passes per 90"])).round(2)
#df.sort_values(by="Passing Tendency", ascending=False).head(50)

# Proactivity (Fouls?)
df["Proactivity"] = df["PAdj Interceptions"] / (df["Shots blocked per 90"] + df["PAdj Sliding tackles"])

# Successful dribbles 
df["Successful dribbles per 90"] = df["Dribbles per 90"] * df["Successful dribbles, %"]

df["Fouls per 90"] = -(df["Fouls per 90"])

#df["Fouls per Duel"] = df["Fouls per 90"] / df["Defensive duels per 90"]

# %%
df["Proactivity"][df["Proactivity"] == inf] = 0
df["Proactivity"][numpy.isinf(df["Proactivity"])] = 0

# %%
df.fillna(0, inplace=True)
#df.isnull().sum()

# %% [markdown]
# ### Create Percentiles (only used for Tableau charts)

# %%
# Create a list of all leagues to subset dataframes
leagues = df["League"].unique().tolist()

# %%
# Initiate an empty dictionary that includes all new dataframes
d={}

df_per = df[(df["Main Position"] == "RB") | (df["Main Position"] == "LB")]

for league in leagues:
    d[league] = df_per[df_per["League"] == league]

# %%
# Run for loop to calculate percentiles per metric per dataframe 
for key in d.keys():
    for i in d[key].iloc[:,23:]:
        d[key][i] = ((d[key][i].rank(pct=True))*100).round(2)

# %% [markdown]
# # 2. Preprocessing the Data

# %%
kpi1 = "PAdj Interceptions"
kpi2 = "Aerial duels won, %"
kpi3 = "Defensive duels won, %"
kpi4 = "Fouls per 90"
kpi5 = "Deep completions per 90"
kpi6 = "Successful dribbles, %"
kpi7 = "Progressive runs per 90"
kpi8 = "Accurate short / medium passes, %"
kpi9 = "Turnover"
kpi10 = "Progressive passes per 90"

w1 = 0.1
w2 = 0.05
w3 = 0.1
w4 = 0.1
w5 = 0.05
w6 = 0.05
w7 = 0.1
w8 = 0.2
w9 = 0.15
w10 = 0.1

# %%
# Define Stats
cols_stats = [kpi1, kpi2, kpi3, kpi4, kpi5, kpi6, kpi7, kpi8, kpi9, kpi10]

# %%
# Create a dataframe of numerical values by selecting all numerical columns
df_stats = df[cols_stats]
df_stats.head()
# Out:
#    PAdj Interceptions  Aerial duels won, %  Defensive duels won, %  \
# 0                5.91                48.65                   62.50
# 1                6.45                53.15                   68.21
# 2                9.03                57.32                   65.11
# 3                7.37                42.66                   63.16
# 4                6.51                41.67                   65.16
#
#    Fouls per 90  Deep completions per 90  Successful dribbles, %  \
# 0         -0.36                     0.57                   72.58
# 1         -0.92                     0.32                   50.00
# 2         -1.72                     0.36                   56.00
# 3         -1.11                     0.34                   59.38
# 4         -1.23                     0.52                   56.76
#
#    Progressive runs per 90  Accurate short / medium passes, %  Turnover  \
# 0                     1.90                              86.04     -2.18
# 1                     0.60                              86.19     -1.43
# 2                     1.70                              87.02     -4.65
# 3                     1.50                              87.43     -4.43
# 4                     0.95                              82.37     -2.13
#
#    Progressive passes per 90
# 0                      12.44
# 1                       7.51
# 2                       9.23
# 3                       6.94
# 4                       6.76

# %%
# Check for NULL values
df_stats.fillna(0, inplace=True)
#df_stats.isnull().sum()

# %%
# Standardization
x = df_stats
scaler = StandardScaler()

# Option2
x[cols_stats] = scaler.fit_transform(x)

# %%
europe = ["Austria 1", "Austria 2", "Belgium 1", "Belgium 2", "Croatia", "Czech 1", "Czech 2", "Denmark 1",
         "Denmark 2", "England 1", "England 2", "England 3", "Finland", "France 1", "France 2", "France 3",
         "Germany 1", "Germany 2", "Germany 3", "Greece 1", "Hungary 1", "Italy 1", "Italy 2", "Netherlands 1",
         "Netherlands 2", "Norway", "Poland 1", "Poland 2", "Portugal 1", "Portugal 2", "Romania 1",
         "Romania 2", "Russia 1", "Russia 2", "Scotland 1", "Scotland 2", "Serbia", "Slovakia", "Slovenia",
         "Spain 1", "Spain 2", "Sweden 1", "Sweden 2", "Switzerland 1", "Switzerland 2", 
         "Turkey 1", "Turkey 2", "Ukraine 1", "Ukraine 2"]

# %% [markdown]
# # 3. Calculate Similarity

# %%
def calculate_similarity(player, squad, value, age):
    
    dist1 = float(df[kpi1][(df["ID"] == player + " (" + squad + ")")])
    dist2 = float(df[kpi2][(df["ID"] == player + " (" + squad + ")")])
    dist3 = float(df[kpi3][(df["ID"] == player + " (" + squad + ")")])
    dist4 = float(df[kpi4][(df["ID"] == player + " (" + squad + ")")])
    dist5 = float(df[kpi5][(df["ID"] == player + " (" + squad + ")")])
    dist6 = float(df[kpi6][(df["ID"] == player + " (" + squad + ")")])
    dist7 = float(df[kpi7][(df["ID"] == player + " (" + squad + ")")])
    dist8 = float(df[kpi8][(df["ID"] == player + " (" + squad + ")")])
    dist9 = float(df[kpi9][(df["ID"] == player + " (" + squad + ")")])
    dist10 = float(df[kpi10][(df["ID"] == player + " (" + squad + ")")])
                    
    df["Dist"] = np.sqrt( w1*((dist1 - df[kpi1])**2) + w2*((dist2 - df[kpi2])**2)
                        + w3*((dist3 - df[kpi3])**2) + w4*((dist4 - df[kpi4])**2)  
                        + w5*((dist5 - df[kpi5])**2) + w6*((dist6 - df[kpi6])**2) 
                        + w7*((dist7 - df[kpi7])**2) + w8*((dist8 - df[kpi8])**2) 
                        + w9*((dist9 - df[kpi9])**2) + w10*((dist10 - df[kpi10])**2)
                        )
    
    df["Similarity"] = 1 - df["Dist"]/np.max(df["Dist"])
    
    dff = df[(df["Market value"] < value) & (df["Age"] < age) & (df["Main Position"] == "RB")]
    dff = dff.loc[dff['League'].isin(europe)]
    
    return dff[["ID", "Age", "League", "Market value", "Position", "Dist", "Similarity", kpi1, kpi2, kpi3, kpi4, kpi5, kpi6, kpi7, kpi8, kpi9]].sort_values(by="Similarity", ascending=False).reset_index(drop=True).head(50)

# %%
calculate_similarity("K. Walker", "Manchester City", 5000000, 25)
# Out:
#                                 ID  Age         League  Market value  \
# 0             L. Rota (AEK Athens)   24       Greece 1       1000000
# 1       A. Sampsted (Bodø / Glimt)   24         Norway       1200000
# 2         D. Haruţ (FCS Bucureşti)   23      Romania 1       1000000
# 3            S. Boey (Galatasaray)   21       Turkey 1       4000000
# 4                B. Anang (Žilina)   22       Slovakia        250000
# 5         A. Jallow (IFK Göteborg)   24       Sweden 1       1000000
# 6           E. Kurtulus (Hammarby)   22       Sweden 1       1500000
# 7           N. Markelo (Excelsior)   23  Netherlands 2        250000
# 8                 R. Zeegers (MVV)   22  Netherlands 2        275000
# 9        S. Floranus (Antalyaspor)   23       Turkey 1       1000000
# 10        M. Mijailović (Voždovac)   24         Serbia        400000
# 11     M. Jelassi (Brommapojkarna)   22       Sweden 2        200000
# 12             Y. Regeer (Ajax II)   18  Netherlands 2       2400000
# 13         R. Poole (Lincoln City)   23      England 3        250000
# 14            F. Beijmo (Malmö FF)   24       Sweden 1       1200000
# 15               N. Fadiga (Brest)   22  Netherlands 1        550000
# 16             H. Mendes (Lorient)   24       France 1       3000000
# 17     L. van Gelderen (Groningen)   21  Netherlands 2        650000
# 18            S. Diakite (Ternana)   22        Italy 2        450000
# 19  Y. Romanyuk (Metalist Kharkiv)   24      Ukraine 2        200000
# 20             T. Baldé (Le Havre)   20       France 2       2000000
# 21          B. Balcı (Antalyaspor)   21       Turkey 1       4000000
# 22         Zé Carlos (Gil Vicente)   23     Portugal 1       1500000
# 23              V. Gendrey (Lecce)   22        Italy 2       1700000
# 24              A. Preciado (Genk)   24      Belgium 1       2500000
# 25             H. Uzochokwu (KuPS)   23        Finland        200000
# 26           H. Clarke (Hibernian)   21     Scotland 1        350000
# 27          H. Asmelash (Inhulets)   23      Ukraine 1        300000
# 28      J. Amofa (Go Ahead Eagles)   23  Netherlands 2        100000
# 29              L. Lyratzis (PAOK)   22       Greece 1       1500000
# 30           Salva Ferrer (Spezia)   24        Italy 1       1300000
# 31        A. Iljazovski (Hvidovre)   24      Denmark 2        250000
# 32   D. Shynkarenko (Hirnyk-Sport)   21      Ukraine 2        125000
# 33             J. Moutachy (Niort)   24       France 2        600000
# 34               C. Blackman (DAC)   24       Slovakia        450000
# 35            V. Fors (Eskilstuna)   23       Sweden 2        150000
# 36            Sergio López (Basel)   23  Switzerland 1       1000000
# 37              A. Solano (Rijeka)   24        Croatia        850000
# 38              A. Mäenpää (Ilves)   24        Finland        150000
# 39      Carlos Isaac (Real Oviedo)   24        Spain 2        200000
# 40                A. Bamba (Paris)   22       France 2       1300000
# 41  T. Căpușă (Chindia Târgovişte)   24      Romania 1        850000
# 42          M. Şahin (Manisa BBSK)   21       Turkey 2        175000
# 43                  B. Varju (MTK)   21      Hungary 1        250000
# 44        N. Kalugin (Neftekhimik)   24       Russia 2        550000
# 45  D. Denisov (Spartak Moskva II)   19       Russia 2        500000
# 46            A. Csongvai (Újpest)   21      Hungary 1        400000
# 47             A. Ralston (Celtic)   23     Scotland 1       2000000
# 48             G. Kalulu (Lorient)   24       France 2       2500000
# 49         M. Okyar (Keçiörengücü)   23       Turkey 2        250000
#
#           Position      Dist  Similarity  PAdj Interceptions  \
# 0               RB  2.198713    0.955853                4.78
# 1               RB  2.371027    0.952393                7.37
# 2      RB, CB, LCB  2.375406    0.952305                5.11
# 3               RB  2.499791    0.949808                5.73
# 4           RB, LB  2.504224    0.949719                8.09
# 5           RB, LB  2.948047    0.940807                5.65
# 6          RB, RCB  3.003729    0.939689                4.73
# 7               RB  3.063230    0.938495                5.25
# 8          RB, RCB  3.247810    0.934788                5.09
# 9               RB  3.262445    0.934495                5.37
# 10     RB, RCB, CB  3.352395    0.932689                7.35
# 11              RB  3.451409    0.930700                5.87
# 12  RB, RDMF, RCMF  3.527076    0.929181                8.59
# 13    RB, LCB, RCB  3.566794    0.928384                7.36
# 14         RB, RWB  3.668320    0.926345                6.40
# 15              RB  3.738395    0.924938                4.58
# 16         RB, RCB  3.742179    0.924862                4.61
# 17         RB, RCB  3.765867    0.924387                7.04
# 18         RB, RCB  3.788935    0.923923                7.50
# 19     RB, LB, RWB  3.873199    0.922232                5.48
# 20         RB, RWB  3.908040    0.921532                4.55
# 21         RB, RWB  3.925719    0.921177                4.27
# 22              RB  3.942087    0.920848                7.91
# 23              RB  3.974654    0.920194                7.44
# 24              RB  4.073596    0.918208                5.91
# 25         RB, RWB  4.097820    0.917721                4.32
# 26    RB, RCB, RWB  4.135564    0.916964                6.35
# 27          RB, LB  4.172077    0.916230                4.25
# 28         RB, RCB  4.201664    0.915636                7.50
# 29              RB  4.219589    0.915276                7.86
# 30    RB, LB, RDMF  4.289400    0.913875                4.92
# 31              RB  4.337206    0.912915                8.15
# 32              RB  4.339121    0.912876                7.25
# 33              RB  4.376798    0.912120                5.09
# 34              RB  4.379918    0.912057                5.47
# 35              RB  4.398205    0.911690                6.72
# 36              RB  4.407621    0.911501                6.17
# 37         RB, RWB  4.428216    0.911088                7.16
# 38              RB  4.458808    0.910473                4.05
# 39              RB  4.474664    0.910155                7.86
# 40         RB, RCB  4.527231    0.909099                5.04
# 41         RB, RCB  4.531440    0.909015                6.89
# 42          RB, LB  4.533038    0.908983                7.79
# 43         RB, RCB  4.537709    0.908889                6.71
# 44         RB, RCB  4.560171    0.908438                5.70
# 45         RB, RCB  4.596530    0.907708                6.91
# 46   RB, LCB, RDMF  4.621783    0.907201                6.71
# 47              RB  4.644549    0.906744                8.46
# 48          RB, LB  4.652403    0.906586                4.73
# 49        RB, LCMF  4.670896    0.906215                6.91
#
#     Aerial duels won, %  Defensive duels won, %  Fouls per 90  \
# 0                 53.85                   61.03         -1.04
# 1                 54.84                   64.91         -0.58
# 2                 50.00                   63.24         -0.78
# 3                 48.48                   60.50         -1.46
# 4                 47.62                   67.54         -0.56
# 5                 55.22                   61.24         -0.98
# 6                 57.38                   64.16         -0.85
# 7                 54.84                   68.24         -1.27
# 8                 45.45                   60.17         -0.94
# 9                 50.00                   58.67         -0.88
# 10                52.44                   56.68         -1.71
# 11                46.43                   63.33         -1.33
# 12                45.98                   62.71         -0.88
# 13                53.85                   61.41         -0.58
# 14                50.00                   61.59         -1.16
# 15                51.28                   62.82         -1.08
# 16                47.19                   71.49         -1.03
# 17                48.84                   57.07         -1.20
# 18                59.32                   61.60         -1.88
# 19                62.71                   63.16         -1.24
# 20                47.06                   66.88         -0.45
# 21                45.16                   64.16         -1.01
# 22                57.45                   65.69         -0.64
# 23                53.16                   63.13         -0.88
# 24                51.22                   64.84         -1.20
# 25                53.85                   67.83         -0.86
# 26                59.33                   61.17         -0.66
# 27                46.15                   60.67         -0.87
# 28                58.06                   66.46         -0.82
# 29                37.50                   66.22         -0.56
# 30                54.72                   63.39         -0.71
# 31                49.58                   61.99         -1.12
# 32                47.92                   59.23         -1.50
# 33                55.07                   59.93         -1.08
# 34                60.87                   63.47         -1.24
# 35                51.79                   54.59         -1.69
# 36                45.83                   58.26         -0.36
# 37                61.90                   63.92         -0.99
# 38                55.56                   69.19         -0.77
# 39                56.60                   59.46         -1.11
# 40                65.71                   64.79         -1.33
# 41                56.96                   59.71         -0.77
# 42                50.00                   68.75         -0.83
# 43                55.88                   61.17         -0.68
# 44                57.52                   57.69         -1.40
# 45                59.72                   60.93         -1.25
# 46                51.11                   59.44         -1.14
# 47                67.23                   55.56         -1.25
# 48                56.41                   74.15         -1.18
# 49                55.56                   62.81         -1.40
#
#     Deep completions per 90  Successful dribbles, %  Progressive runs per 90  \
# 0                      0.31                   60.71                     2.03
# 1                      1.23                   55.88                     6.08
# 2                      0.37                   59.09                     0.78
# 3                      0.31                   52.94                     2.15
# 4                      0.84                   51.52                     1.50
# 5                      0.40                   53.68                     2.16
# 6                      0.99                   63.64                     1.50
# 7                      0.38                   52.38                     1.95
# 8                      0.28                   50.00                     1.41
# 9                      0.62                   55.56                     0.44
# 10                     0.40                   53.85                     1.55
# 11                     1.01                   63.64                     4.60
# 12                     1.46                   49.06                     2.04
# 13                     0.44                   59.42                     1.21
# 14                     1.10                   39.13                     2.21
# 15                     0.28                   51.49                     1.73
# 16                     0.11                   50.77                     1.21
# 17                     0.58                   55.10                     1.60
# 18                     0.34                   46.51                     1.96
# 19                     0.96                   56.52                     2.65
# 20                     0.58                   60.38                     3.19
# 21                     0.75                   52.50                     0.93
# 22                     0.68                   53.70                     1.49
# 23                     0.67                   60.00                     1.43
# 24                     1.32                   64.20                     2.90
# 25                     0.79                   62.22                     1.78
# 26                     0.83                   54.55                     1.82
# 27                     0.77                   47.37                     1.25
# 28                     0.56                   67.21                     1.50
# 29                     0.65                   47.06                     1.68
# 30                     0.33                   52.63                     1.20
# 31                     0.48                   52.00                     1.48
# 32                     0.25                   55.56                     0.81
# 33                     0.21                   43.66                     1.57
# 34                     0.65                   52.22                     2.67
# 35                     0.93                   66.10                     2.45
# 36                     0.54                   68.00                     2.78
# 37                     0.30                   57.14                     1.68
# 38                     0.35                   50.88                     0.96
# 39                     0.33                   48.72                     1.49
# 40                     0.09                   42.86                     1.15
# 41                     0.16                   51.35                     0.74
# 42                     0.33                   66.67                     2.37
# 43                     0.24                   70.27                     1.39
# 44                     0.38                   58.82                     0.54
# 45                     0.40                   66.67                     1.50
# 46                     0.55                   41.94                     0.78
# 47                     1.18                   61.61                     1.94
# 48                     0.41                   52.63                     1.76
# 49                     0.33                   56.52                     0.94
#
#     Accurate short / medium passes, %  Turnover
# 0                               93.12     -2.60
# 1                               91.63     -2.82
# 2                               90.90     -1.64
# 3                               90.93     -2.53
# 4                               92.77     -1.89
# 5                               88.59     -2.85
# 6                               92.55     -4.12
# 7                               90.32     -4.07
# 8                               88.94     -1.22
# 9                               89.31     -1.15
# 10                              88.76     -1.80
# 11                              91.71     -3.82
# 12                              88.72     -3.34
# 13                              87.63     -1.46
# 14                              90.65     -1.89
# 15                              87.65     -3.64
# 16                              93.00     -1.58
# 17                              88.06     -2.36
# 18                              88.43     -3.59
# 19                              88.40     -4.68
# 20                              89.00     -3.44
# 21                              87.35     -1.82
# 22                              86.88     -3.12
# 23                              86.79     -2.69
# 24                              88.17     -3.84
# 25                              88.57     -2.78
# 26                              86.44     -3.60
# 27                              86.90     -1.54
# 28                              90.56     -1.98
# 29                              93.21     -3.18
# 30                              85.36     -1.58
# 31                              85.41     -2.55
# 32                              85.81     -1.56
# 33                              86.67     -3.74
# 34                              86.45     -4.86
# 35                              89.92     -2.24
# 36                              90.43     -2.33
# 37                              86.54     -2.97
# 38                              86.91     -3.78
# 39                              85.74     -2.22
# 40                              89.43     -1.86
# 41                              85.16     -2.08
# 42                              89.57     -2.09
# 43                              90.18     -1.71
# 44                              85.86     -0.97
# 45                              88.04     -1.71
# 46                              86.49     -1.36
# 47                              92.02     -3.20
# 48                              89.10     -2.85
# 49                              85.36     -3.28
